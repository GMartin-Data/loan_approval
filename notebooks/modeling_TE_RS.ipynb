# %% [markdown]
# # Imports

# %%
from typing import List

import category_encoders as ce
import numpy as np
import pandas as pd
from scipy.stats import randint as sp_randint
from scipy.stats import uniform
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.compose import ColumnTransformer
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import SelectFromModel
from sklearn.metrics import f1_score
from sklearn.model_selection import RandomizedSearchCV, train_test_split
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, StandardScaler

# %% [markdown]
# # Data Loading

# %%
# %%time
df = pd.read_csv("../data/cleaned_dataset.csv", index_col=0)
# Out:
# CPU times: user 2.46 s, sys: 276 ms, total: 2.73 s
# Wall time: 2.75 s

# %% [markdown]
# # Droping Useless Columns

# %%
df = df.drop(columns=['LoanNr_ChkDgt', 'Name'])

# %% [markdown]
# # Separating Features and Target

# %%
X = df.copy()
y = X.pop("MIS_Status")

# %% [markdown]
# # Hold-Out

# %%
# Stratify with y by default
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=0.05,
                                                    stratify=y,
                                                    random_state=42)

# %% [markdown]
# # Model1: Target Encoding With `RandomForestClassifier`

# %% [markdown]
# ## Encoding Target

# %%
lbl_enc = LabelEncoder()

y_train = lbl_enc.fit_transform(y_train)
y_test = lbl_enc.transform(y_test)

# %% [markdown]
# ## Preprocessing

# %%
# Splitting columns
num_cols = ["Term", "NoEmp", "CreateJob", "RetainedJob",
            "GrAppv", "SBA_Appv"]

bin_cols = df.select_dtypes("bool").columns

nom_cols = ["UrbanRural", "RevLineCr", "LowDoc"]

cyc_cols = ["ApprovalMonth", "ApprovalDoW"]

tgt_cols = ["State", "BankState", "NAICS", "Bank", "City"]

# %% [markdown]
# ## "Simple" Nominal And Numerical Processes

# %%
std_scl = StandardScaler()
ohe_bin = OneHotEncoder(drop="if_binary",
                        sparse_output=False,
                        handle_unknown="ignore")
ohe_nom = OneHotEncoder(sparse_output=False,  # No drop="first" with a nonlinear model
                        handle_unknown="ignore")

# %% [markdown]
# ## Cyclical Encoding

# %%
class CyclicalEncoder(BaseEstimator, TransformerMixin):
    """Meant to encode time data with cycles (days of week, month...)"""
    def __init__(self, column_name, cycle_length):
        self.column_name = column_name
        self.cycle_length = cycle_length

    def fit(self, X, y=None):
        # No fitting needed, implemented for compatibility with sklearn's API
        return self

    def transform(self, X, y=None):
        # Apply cyclical encoding directly without needing to fit
        X = X.copy()
        values = X[self.column_name]
        # Create the cyclical features
        X[f'{self.column_name}_sin'] = np.sin(2 * np.pi * values / self.cycle_length)
        X[f'{self.column_name}_cos'] = np.cos(2 * np.pi * values / self.cycle_length)
        # Drop the original column
        X.drop(columns=[self.column_name], inplace=True)
        return X

    def get_feature_names_out(self, input_features=None):
        # Generate names for the output features
        return np.array(
          [f'{self.column_name}_sin', f'{self.column_name}_cos'], dtype=object
        )

# %%
cyc_dow = CyclicalEncoder("ApprovalDoW", 7)
cyc_mth = CyclicalEncoder("ApprovalMonth", 12)

# %% [markdown]
# ## Target Encoding for `Bank`, `City`, `State`, `BankState`

# %%
tgt_enc = ce.TargetEncoder(cols=tgt_cols)

# %%
# %%time
# Test
X_train_tgt = tgt_enc.fit_transform(X_train, y_train)
X_train_tgt
# Out:
# CPU times: user 3.99 s, sys: 745 ms, total: 4.73 s
# Wall time: 4.74 s
#             City     State      Bank  BankState  SameState     NAICS  \
# 52158   0.776280  0.820586  0.732058   0.779467      False  0.772481
# 374932  0.858277  0.800739  0.872016   0.831345       True  0.766984
# 716138  0.806424  0.814921  0.938389   0.917150      False  0.916683
# 192181  0.789573  0.802920  0.893810   0.706389      False  0.793372
# 140792  0.796371  0.814921  1.000000   0.779467       True  0.845807
# ...          ...       ...       ...        ...        ...       ...
# 448689  0.847227  0.833083  0.928313   0.872163       True  0.909197
# 755744  0.927152  0.925362  0.925305   0.945354       True  0.772481
# 53966   0.878378  0.814921  0.829540   0.779467       True  0.751065
# 576823  0.878613  0.772574  0.904315   0.777417       True  0.845807
# 415230  0.779736  0.820586  0.831018   0.869848      False  0.766984
#
#         ApprovalMonth  ApprovalDoW  Recession  Term  NewExist  NoEmp  \
# 52158               7            0      False    82     False     10
# 374932              3            4      False    64     False      8
# 716138              8            3      False    84     False     15
# 192181              3            2       True   120     False      5
# 140792              5            1      False   240     False     12
# ...               ...          ...        ...   ...       ...    ...
# 448689             11            4      False    13     False      5
# 755744             12            2      False    60     False      5
# 53966               7            0      False   120     False      1
# 576823              9            0      False   120     False     78
# 415230              4            1      False    84     False      5
#
#         CreateJob  RetainedJob  Franchise UrbanRural RevLineCr LowDoc  \
# 52158           0            0      False          M   Unknown      N
# 374932          0            0      False          U         N      N
# 716138          0            0      False          M         N      N
# 192181          2            5      False          R         N      N
# 140792          8            0      False          U   Unknown      N
# ...           ...          ...        ...        ...       ...    ...
# 448689          0            5      False          R         N      N
# 755744          0            0      False          M         N      N
# 53966           0            0      False          M         N      Y
# 576823          0            0      False          U         N      N
# 415230          0            5      False          U         Y      N
#
#            GrAppv  SBA_Appv
# 52158    540000.0  405000.0
# 374932    70000.0   52500.0
# 716138   120000.0  105600.0
# 192181   210000.0  105000.0
# 140792   422000.0  422000.0
# ...           ...       ...
# 448689    41000.0   20500.0
# 755744    50000.0   44000.0
# 53966     50000.0   40000.0
# 576823  1000000.0  750000.0
# 415230    50000.0   25000.0
#
# [852267 rows x 20 columns]

# %%
preproc1 = ColumnTransformer(
    transformers = [
        ("num", std_scl, num_cols),
        ("bin", ohe_bin, bin_cols),
        ("nom", ohe_nom, nom_cols),
        ("cyc_mth", cyc_mth, ["ApprovalMonth"]),
        ("cyc_dow", cyc_dow, ["ApprovalDoW"]),
        ("tgt_enc", tgt_enc, tgt_cols),
    ],
    verbose_feature_names_out=False
)
preproc1.set_output(transform="pandas")
# Out:
# ColumnTransformer(transformers=[('num', StandardScaler(),
#                                  ['Term', 'NoEmp', 'CreateJob', 'RetainedJob',
#                                   'GrAppv', 'SBA_Appv']),
#                                 ('bin',
#                                  OneHotEncoder(drop='if_binary',
#                                                handle_unknown='ignore',
#                                                sparse_output=False),
#                                  Index(['SameState', 'Recession', 'NewExist', 'Franchise'], dtype='object')),
#                                 ('nom',
#                                  OneHotEncoder(handle_unknown='ignore',
#                                                sparse_output=False),
#                                  ['UrbanRu...vLineCr', 'LowDoc']),
#                                 ('cyc_mth',
#                                  CyclicalEncoder(column_name='ApprovalMonth',
#                                                  cycle_length=12),
#                                  ['ApprovalMonth']),
#                                 ('cyc_dow',
#                                  CyclicalEncoder(column_name='ApprovalDoW',
#                                                  cycle_length=7),
#                                  ['ApprovalDoW']),
#                                 ('tgt_enc',
#                                  TargetEncoder(cols=['State', 'BankState',
#                                                      'NAICS', 'Bank', 'City']),
#                                  ['State', 'BankState', 'NAICS', 'Bank',
#                                   'City'])],
#                   verbose_feature_names_out=False)

# %%
# %%time
# Test
X_train_tr = preproc1.fit_transform(X_train, y_train)
X_train_tr
# Out:
# CPU times: user 4.67 s, sys: 512 ms, total: 5.18 s
# Wall time: 5.19 s
#             Term     NoEmp  CreateJob  RetainedJob    GrAppv  SBA_Appv  \
# 52158  -0.365827 -0.019158  -0.035608    -0.045527  1.224734  1.117235
# 374932 -0.593990 -0.045825  -0.035608    -0.045527 -0.434501 -0.425997
# 716138 -0.340475  0.047508  -0.035608    -0.045527 -0.257986 -0.193527
# 192181  0.115851 -0.085824  -0.027137    -0.024389  0.059739 -0.196154
# 140792  1.636939  0.007508  -0.001724    -0.045527  0.808160  1.191661
# ...          ...       ...        ...          ...       ...       ...
# 448689 -1.240452 -0.085824  -0.035608    -0.024389 -0.536879 -0.566092
# 755744 -0.644693 -0.085824  -0.035608    -0.045527 -0.505106 -0.463210
# 53966   0.115851 -0.139157  -0.035608    -0.045527 -0.505106 -0.480722
# 576823  0.115851  0.887501  -0.035608    -0.045527  2.848666  2.627633
# 415230 -0.340475 -0.085824  -0.035608    -0.024389 -0.505106 -0.546391
#
#         SameState_True  Recession_True  NewExist_True  Franchise_True  ...  \
# 52158              0.0             0.0            0.0             0.0  ...
# 374932             1.0             0.0            0.0             0.0  ...
# 716138             0.0             0.0            0.0             0.0  ...
# 192181             0.0             1.0            0.0             0.0  ...
# 140792             1.0             0.0            0.0             0.0  ...
# ...                ...             ...            ...             ...  ...
# 448689             1.0             0.0            0.0             0.0  ...
# 755744             1.0             0.0            0.0             0.0  ...
# 53966              1.0             0.0            0.0             0.0  ...
# 576823             1.0             0.0            0.0             0.0  ...
# 415230             0.0             0.0            0.0             0.0  ...
#
#         LowDoc_Y  ApprovalMonth_sin  ApprovalMonth_cos  ApprovalDoW_sin  \
# 52158        0.0      -5.000000e-01      -8.660254e-01         0.000000
# 374932       0.0       1.000000e+00       6.123234e-17        -0.433884
# 716138       0.0      -8.660254e-01      -5.000000e-01         0.433884
# 192181       0.0       1.000000e+00       6.123234e-17         0.974928
# 140792       0.0       5.000000e-01      -8.660254e-01         0.781831
# ...          ...                ...                ...              ...
# 448689       0.0      -5.000000e-01       8.660254e-01        -0.433884
# 755744       0.0      -2.449294e-16       1.000000e+00         0.974928
# 53966        1.0      -5.000000e-01      -8.660254e-01         0.000000
# 576823       0.0      -1.000000e+00      -1.836970e-16         0.000000
# 415230       0.0       8.660254e-01      -5.000000e-01         0.781831
#
#         ApprovalDoW_cos     State  BankState     NAICS      Bank      City
# 52158          1.000000  0.820586   0.779467  0.772481  0.732058  0.776280
# 374932        -0.900969  0.800739   0.831345  0.766984  0.872016  0.858277
# 716138        -0.900969  0.814921   0.917150  0.916683  0.938389  0.806424
# 192181        -0.222521  0.802920   0.706389  0.793372  0.893810  0.789573
# 140792         0.623490  0.814921   0.779467  0.845807  1.000000  0.796371
# ...                 ...       ...        ...       ...       ...       ...
# 448689        -0.900969  0.833083   0.872163  0.909197  0.928313  0.847227
# 755744        -0.222521  0.925362   0.945354  0.772481  0.925305  0.927152
# 53966          1.000000  0.814921   0.779467  0.751065  0.829540  0.878378
# 576823         1.000000  0.772574   0.777417  0.845807  0.904315  0.878613
# 415230         0.623490  0.820586   0.869848  0.766984  0.831018  0.779736
#
# [852267 rows x 27 columns]

# %% [markdown]
# ## Estimator

# %% [markdown]
# ### Train

# %%
rfc1 = RandomForestClassifier(random_state=0)

model1 = make_pipeline(preproc1, rfc1)
model1
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   ['Term', 'NoEmp', 'CreateJob',
#                                                    'RetainedJob', 'GrAppv',
#                                                    'SBA_Appv']),
#                                                  ('bin',
#                                                   OneHotEncoder(drop='if_binary',
#                                                                 handle_unknown='ignore',
#                                                                 sparse_output=False),
#                                                   Index(['SameState', 'Recession', 'NewExist', 'Franchise'], dtype='object')),
#                                                  ('nom',
#                                                   OneHotEncoder(handle_unknown='i...
#                                                   CyclicalEncoder(column_name='ApprovalMonth',
#                                                                   cycle_length=12),
#                                                   ['ApprovalMonth']),
#                                                  ('cyc_dow',
#                                                   CyclicalEncoder(column_name='ApprovalDoW',
#                                                                   cycle_length=7),
#                                                   ['ApprovalDoW']),
#                                                  ('tgt_enc',
#                                                   TargetEncoder(cols=['State',
#                                                                       'BankState',
#                                                                       'NAICS',
#                                                                       'Bank',
#                                                                       'City']),
#                                                   ['State', 'BankState',
#                                                    'NAICS', 'Bank', 'City'])],
#                                    verbose_feature_names_out=False)),
#                 ('randomforestclassifier',
#                  RandomForestClassifier(random_state=0))])

# %% [markdown]
# ### Accuracy

# %%
# %%time
model1.fit(X_train, y_train)
model1.score(X_test, y_test)
# Out:
# CPU times: user 3min 3s, sys: 884 ms, total: 3min 4s
# Wall time: 3min 4s
# 0.9415029984171924

# %% [markdown]
# ### $F_1$ Macro

# %%
y_pred = model1.predict(X_test)
f1_score(y_test, y_pred, average="macro")
# Out:
# 0.8923730139876496

# %% [markdown]
# ### Feature Importances

# %%
importances = model1[-1].feature_importances_
indices = np.argsort(importances)[::-1]
feat_labels = X_train_tr.columns
tups = [(feat_labels[i], importances[i]) for i in indices]
df_imp = pd.DataFrame(tups, columns=["feature", "importance"])
df_imp
# Out:
#               feature  importance
# 0                Term    0.400459
# 1                Bank    0.105542
# 2                City    0.060206
# 3            SBA_Appv    0.054517
# 4           BankState    0.048428
# 5              GrAppv    0.044554
# 6               State    0.034481
# 7               NAICS    0.028265
# 8               NoEmp    0.028243
# 9         RetainedJob    0.025398
# 10  ApprovalMonth_sin    0.019448
# 11  ApprovalMonth_cos    0.019356
# 12       UrbanRural_M    0.015031
# 13    ApprovalDoW_sin    0.014908
# 14     Recession_True    0.014132
# 15     SameState_True    0.013442
# 16          CreateJob    0.012821
# 17    ApprovalDoW_cos    0.011529
# 18        RevLineCr_Y    0.009217
# 19      NewExist_True    0.007492
# 20  RevLineCr_Unknown    0.007307
# 21        RevLineCr_N    0.007184
# 22       UrbanRural_U    0.006663
# 23     Franchise_True    0.003175
# 24       UrbanRural_R    0.003034
# 25           LowDoc_Y    0.002633
# 26           LowDoc_N    0.002537

# %%
def select_feats_by_importance(thresh: float) -> List[str]:
    """Return a list of features by decreasing feature importance"""
    return (
        df_imp
        .query("importance >= @thresh")
        .loc[:, "feature"]
        .to_list()
    )

def select_feats_by_number(n: int) -> List[str]:
    """Return a list of n most important features"""
    return df_imp.loc[:(n - 1), "feature"]

# %% [markdown]
# ### Keeping Only Features Over 1% Importance

# %%
kept_feats = select_feats_by_importance(0.01)
kept_feats
# Out:
# ['Term',
#  'Bank',
#  'City',
#  'SBA_Appv',
#  'BankState',
#  'GrAppv',
#  'State',
#  'NAICS',
#  'NoEmp',
#  'RetainedJob',
#  'ApprovalMonth_sin',
#  'ApprovalMonth_cos',
#  'UrbanRural_M',
#  'ApprovalDoW_sin',
#  'Recession_True',
#  'SameState_True',
#  'CreateJob',
#  'ApprovalDoW_cos']

# %%
select_feats_by_number(10)
# Out:
# 0           Term
# 1           Bank
# 2           City
# 3       SBA_Appv
# 4      BankState
# 5         GrAppv
# 6          State
# 7          NAICS
# 8          NoEmp
# 9    RetainedJob
# Name: feature, dtype: object

# %% [markdown]
# # Model2: `SelectFromModel` After Preprocessing

# %% [markdown]
# ## Pipeline

# %%
rfc = RandomForestClassifier(random_state=0)

# %%
sfm = SelectFromModel(rfc, threshold=0.01)

# %%
preproc_select = make_pipeline(preproc1, sfm)
preproc_select.set_output(transform="pandas")
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   ['Term', 'NoEmp', 'CreateJob',
#                                                    'RetainedJob', 'GrAppv',
#                                                    'SBA_Appv']),
#                                                  ('bin',
#                                                   OneHotEncoder(drop='if_binary',
#                                                                 handle_unknown='ignore',
#                                                                 sparse_output=False),
#                                                   Index(['SameState', 'Recession', 'NewExist', 'Franchise'], dtype='object')),
#                                                  ('nom',
#                                                   OneHotEncoder(handle_unknown='i...
#                                                   ['ApprovalMonth']),
#                                                  ('cyc_dow',
#                                                   CyclicalEncoder(column_name='ApprovalDoW',
#                                                                   cycle_length=7),
#                                                   ['ApprovalDoW']),
#                                                  ('tgt_enc',
#                                                   TargetEncoder(cols=['State',
#                                                                       'BankState',
#                                                                       'NAICS',
#                                                                       'Bank',
#                                                                       'City']),
#                                                   ['State', 'BankState',
#                                                    'NAICS', 'Bank', 'City'])],
#                                    verbose_feature_names_out=False)),
#                 ('selectfrommodel',
#                  SelectFromModel(estimator=RandomForestClassifier(random_state=0),
#                                  threshold=0.01))])

# %%
# %%time
X_train_sel = preproc_select.fit_transform(X_train, y_train)
X_train_sel
# Out:
# CPU times: user 3min 10s, sys: 788 ms, total: 3min 11s
# Wall time: 3min 11s
#             Term     NoEmp  CreateJob  RetainedJob    GrAppv  SBA_Appv  \
# 52158  -0.365827 -0.019158  -0.035608    -0.045527  1.224734  1.117235
# 374932 -0.593990 -0.045825  -0.035608    -0.045527 -0.434501 -0.425997
# 716138 -0.340475  0.047508  -0.035608    -0.045527 -0.257986 -0.193527
# 192181  0.115851 -0.085824  -0.027137    -0.024389  0.059739 -0.196154
# 140792  1.636939  0.007508  -0.001724    -0.045527  0.808160  1.191661
# ...          ...       ...        ...          ...       ...       ...
# 448689 -1.240452 -0.085824  -0.035608    -0.024389 -0.536879 -0.566092
# 755744 -0.644693 -0.085824  -0.035608    -0.045527 -0.505106 -0.463210
# 53966   0.115851 -0.139157  -0.035608    -0.045527 -0.505106 -0.480722
# 576823  0.115851  0.887501  -0.035608    -0.045527  2.848666  2.627633
# 415230 -0.340475 -0.085824  -0.035608    -0.024389 -0.505106 -0.546391
#
#         SameState_True  Recession_True  UrbanRural_M  ApprovalMonth_sin  \
# 52158              0.0             0.0           1.0      -5.000000e-01
# 374932             1.0             0.0           0.0       1.000000e+00
# 716138             0.0             0.0           1.0      -8.660254e-01
# 192181             0.0             1.0           0.0       1.000000e+00
# 140792             1.0             0.0           0.0       5.000000e-01
# ...                ...             ...           ...                ...
# 448689             1.0             0.0           0.0      -5.000000e-01
# 755744             1.0             0.0           1.0      -2.449294e-16
# 53966              1.0             0.0           1.0      -5.000000e-01
# 576823             1.0             0.0           0.0      -1.000000e+00
# 415230             0.0             0.0           0.0       8.660254e-01
#
#         ApprovalMonth_cos  ApprovalDoW_sin  ApprovalDoW_cos     State  \
# 52158       -8.660254e-01         0.000000         1.000000  0.820586
# 374932       6.123234e-17        -0.433884        -0.900969  0.800739
# 716138      -5.000000e-01         0.433884        -0.900969  0.814921
# 192181       6.123234e-17         0.974928        -0.222521  0.802920
# 140792      -8.660254e-01         0.781831         0.623490  0.814921
# ...                   ...              ...              ...       ...
# 448689       8.660254e-01        -0.433884        -0.900969  0.833083
# 755744       1.000000e+00         0.974928        -0.222521  0.925362
# 53966       -8.660254e-01         0.000000         1.000000  0.814921
# 576823      -1.836970e-16         0.000000         1.000000  0.772574
# 415230      -5.000000e-01         0.781831         0.623490  0.820586
#
#         BankState     NAICS      Bank      City
# 52158    0.779467  0.772481  0.732058  0.776280
# 374932   0.831345  0.766984  0.872016  0.858277
# 716138   0.917150  0.916683  0.938389  0.806424
# 192181   0.706389  0.793372  0.893810  0.789573
# 140792   0.779467  0.845807  1.000000  0.796371
# ...           ...       ...       ...       ...
# 448689   0.872163  0.909197  0.928313  0.847227
# 755744   0.945354  0.772481  0.925305  0.927152
# 53966    0.779467  0.751065  0.829540  0.878378
# 576823   0.777417  0.845807  0.904315  0.878613
# 415230   0.869848  0.766984  0.831018  0.779736
#
# [852267 rows x 18 columns]

# %%
model = make_pipeline(preproc1, sfm, rfc)

# %% [markdown]
# ## $F_1$ Macro

# %%
# %%time
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
f1_score(y_test, y_pred, average="macro")
# Out:
# CPU times: user 6min 17s, sys: 816 ms, total: 6min 17s
# Wall time: 6min 17s
# 0.8909402350240652

# %%
y_pred = model.predict(X_test)
f1_score(y_test, y_pred, average="macro")
# Out:
# 0.8909402350240652

# %% [markdown]
# # `RandomizedSearch`

# %%
model.get_params()
# Out:
# {'memory': None,
#  'steps': [('columntransformer',
#    ColumnTransformer(transformers=[('num', StandardScaler(),
#                                     ['Term', 'NoEmp', 'CreateJob', 'RetainedJob',
#                                      'GrAppv', 'SBA_Appv']),
#                                    ('bin',
#                                     OneHotEncoder(drop='if_binary',
#                                                   handle_unknown='ignore',
#                                                   sparse_output=False),
#                                     Index(['SameState', 'Recession', 'NewExist', 'Franchise'], dtype='object')),
#                                    ('nom',
#                                     OneHotEncoder(handle_unknown='ignore',
#                                                   sparse_output=False),
#                                     ['UrbanRu...vLineCr', 'LowDoc']),
#                                    ('cyc_mth',
#                                     CyclicalEncoder(column_name='ApprovalMonth',
#                                                     cycle_length=12),
#                                     ['ApprovalMonth']),
#                                    ('cyc_dow',
#                                     CyclicalEncoder(column_name='ApprovalDoW',
#                                                     cycle_length=7),
#                                     ['ApprovalDoW']),
#                                    ('tgt_enc',
#                                     TargetEncoder(cols=['State', 'BankState',
#                                                         'NAICS', 'Bank', 'City']),
#                                     ['State', 'BankState', 'NAICS', 'Bank',
#                                      'City'])],
#                      verbose_feature_names_out=False)),
#   ('selectfrommodel',
#    SelectFromModel(estimator=RandomForestClassifier(random_state=0),
#                    threshold=0.01)),
#   ('randomforestclassifier', RandomForestClassifier(random_state=0))],
#  'verbose': False,
#  'columntransformer': ColumnTransformer(transformers=[('num', StandardScaler(),
#                                   ['Term', 'NoEmp', 'CreateJob', 'RetainedJob',
#                                    'GrAppv', 'SBA_Appv']),
#                                  ('bin',
#                                   OneHotEncoder(drop='if_binary',
#                                                 handle_unknown='ignore',
#                                                 sparse_output=False),
#                                   Index(['SameState', 'Recession', 'NewExist', 'Franchise'], dtype='object')),
#                                  ('nom',
#                                   OneHotEncoder(handle_unknown='ignore',
#                                                 sparse_output=False),
#                                   ['UrbanRu...vLineCr', 'LowDoc']),
#                                  ('cyc_mth',
#                                   CyclicalEncoder(column_name='ApprovalMonth',
#                                                   cycle_length=12),
#                                   ['ApprovalMonth']),
#                                  ('cyc_dow',
#                                   CyclicalEncoder(column_name='ApprovalDoW',
#                                                   cycle_length=7),
#                                   ['ApprovalDoW']),
#                                  ('tgt_enc',
#                                   TargetEncoder(cols=['State', 'BankState',
#                                                       'NAICS', 'Bank', 'City']),
#                                   ['State', 'BankState', 'NAICS', 'Bank',
#                                    'City'])],
#                    verbose_feature_names_out=False),
#  'selectfrommodel': SelectFromModel(estimator=RandomForestClassifier(random_state=0),
#                  threshold=0.01),
#  'randomforestclassifier': RandomForestClassifier(random_state=0),
#  'columntransformer__n_jobs': None,
#  'columntransformer__remainder': 'drop',
#  'columntransformer__sparse_threshold': 0.3,
#  'columntransformer__transformer_weights': None,
#  'columntransformer__transformers': [('num',
#    StandardScaler(),
#    ['Term', 'NoEmp', 'CreateJob', 'RetainedJob', 'GrAppv', 'SBA_Appv']),
#   ('bin',
#    OneHotEncoder(drop='if_binary', handle_unknown='ignore', sparse_output=False),
#    Index(['SameState', 'Recession', 'NewExist', 'Franchise'], dtype='object')),
#   ('nom',
#    OneHotEncoder(handle_unknown='ignore', sparse_output=False),
#    ['UrbanRural', 'RevLineCr', 'LowDoc']),
#   ('cyc_mth',
#    CyclicalEncoder(column_name='ApprovalMonth', cycle_length=12),
#    ['ApprovalMonth']),
#   ('cyc_dow',
#    CyclicalEncoder(column_name='ApprovalDoW', cycle_length=7),
#    ['ApprovalDoW']),
#   ('tgt_enc',
#    TargetEncoder(cols=['State', 'BankState', 'NAICS', 'Bank', 'City']),
#    ['State', 'BankState', 'NAICS', 'Bank', 'City'])],
#  'columntransformer__verbose': False,
#  'columntransformer__verbose_feature_names_out': False,
#  'columntransformer__num': StandardScaler(),
#  'columntransformer__bin': OneHotEncoder(drop='if_binary', handle_unknown='ignore', sparse_output=False),
#  'columntransformer__nom': OneHotEncoder(handle_unknown='ignore', sparse_output=False),
#  'columntransformer__cyc_mth': CyclicalEncoder(column_name='ApprovalMonth', cycle_length=12),
#  'columntransformer__cyc_dow': CyclicalEncoder(column_name='ApprovalDoW', cycle_length=7),
#  'columntransformer__tgt_enc': TargetEncoder(cols=['State', 'BankState', 'NAICS', 'Bank', 'City']),
#  'columntransformer__num__copy': True,
#  'columntransformer__num__with_mean': True,
#  'columntransformer__num__with_std': True,
#  'columntransformer__bin__categories': 'auto',
#  'columntransformer__bin__drop': 'if_binary',
#  'columntransformer__bin__dtype': numpy.float64,
#  'columntransformer__bin__feature_name_combiner': 'concat',
#  'columntransformer__bin__handle_unknown': 'ignore',
#  'columntransformer__bin__max_categories': None,
#  'columntransformer__bin__min_frequency': None,
#  'columntransformer__bin__sparse_output': False,
#  'columntransformer__nom__categories': 'auto',
#  'columntransformer__nom__drop': None,
#  'columntransformer__nom__dtype': numpy.float64,
#  'columntransformer__nom__feature_name_combiner': 'concat',
#  'columntransformer__nom__handle_unknown': 'ignore',
#  'columntransformer__nom__max_categories': None,
#  'columntransformer__nom__min_frequency': None,
#  'columntransformer__nom__sparse_output': False,
#  'columntransformer__cyc_mth__column_name': 'ApprovalMonth',
#  'columntransformer__cyc_mth__cycle_length': 12,
#  'columntransformer__cyc_dow__column_name': 'ApprovalDoW',
#  'columntransformer__cyc_dow__cycle_length': 7,
#  'columntransformer__tgt_enc__cols': ['State',
#   'BankState',
#   'NAICS',
#   'Bank',
#   'City'],
#  'columntransformer__tgt_enc__drop_invariant': False,
#  'columntransformer__tgt_enc__handle_missing': 'value',
#  'columntransformer__tgt_enc__handle_unknown': 'value',
#  'columntransformer__tgt_enc__hierarchy': None,
#  'columntransformer__tgt_enc__min_samples_leaf': 20,
#  'columntransformer__tgt_enc__return_df': True,
#  'columntransformer__tgt_enc__smoothing': 10,
#  'columntransformer__tgt_enc__verbose': 0,
#  'selectfrommodel__estimator__bootstrap': True,
#  'selectfrommodel__estimator__ccp_alpha': 0.0,
#  'selectfrommodel__estimator__class_weight': None,
#  'selectfrommodel__estimator__criterion': 'gini',
#  'selectfrommodel__estimator__max_depth': None,
#  'selectfrommodel__estimator__max_features': 'sqrt',
#  'selectfrommodel__estimator__max_leaf_nodes': None,
#  'selectfrommodel__estimator__max_samples': None,
#  'selectfrommodel__estimator__min_impurity_decrease': 0.0,
#  'selectfrommodel__estimator__min_samples_leaf': 1,
#  'selectfrommodel__estimator__min_samples_split': 2,
#  'selectfrommodel__estimator__min_weight_fraction_leaf': 0.0,
#  'selectfrommodel__estimator__monotonic_cst': None,
#  'selectfrommodel__estimator__n_estimators': 100,
#  'selectfrommodel__estimator__n_jobs': None,
#  'selectfrommodel__estimator__oob_score': False,
#  'selectfrommodel__estimator__random_state': 0,
#  'selectfrommodel__estimator__verbose': 0,
#  'selectfrommodel__estimator__warm_start': False,
#  'selectfrommodel__estimator': RandomForestClassifier(random_state=0),
#  'selectfrommodel__importance_getter': 'auto',
#  'selectfrommodel__max_features': None,
#  'selectfrommodel__norm_order': 1,
#  'selectfrommodel__prefit': False,
#  'selectfrommodel__threshold': 0.01,
#  'randomforestclassifier__bootstrap': True,
#  'randomforestclassifier__ccp_alpha': 0.0,
#  'randomforestclassifier__class_weight': None,
#  'randomforestclassifier__criterion': 'gini',
#  'randomforestclassifier__max_depth': None,
#  'randomforestclassifier__max_features': 'sqrt',
#  'randomforestclassifier__max_leaf_nodes': None,
#  'randomforestclassifier__max_samples': None,
#  'randomforestclassifier__min_impurity_decrease': 0.0,
#  'randomforestclassifier__min_samples_leaf': 1,
#  'randomforestclassifier__min_samples_split': 2,
#  'randomforestclassifier__min_weight_fraction_leaf': 0.0,
#  'randomforestclassifier__monotonic_cst': None,
#  'randomforestclassifier__n_estimators': 100,
#  'randomforestclassifier__n_jobs': None,
#  'randomforestclassifier__oob_score': False,
#  'randomforestclassifier__random_state': 0,
#  'randomforestclassifier__verbose': 0,
#  'randomforestclassifier__warm_start': False}

# %%
param_dist = {
    "randomforestclassifier__max_features": ['sqrt', 'log2', None] + list(np.linspace(0.1, 1.0, 10)),
    "randomforestclassifier__min_samples_leaf": sp_randint(1, 20),
    "randomforestclassifier__bootstrap": [True, False],
    "randomforestclassifier__n_estimators": sp_randint(100, 2_000)
}

# %%
# %%time
random_search = RandomizedSearchCV(model,
                                   param_distributions=param_dist,
                                   n_iter=100,
                                   cv=5,
                                   verbose=1,
                                   n_jobs=-1,
                                   random_state=42)
random_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# ---------------------------------------------------------------------------
# _RemoteTraceback                          Traceback (most recent call last)
# _RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/home/martin/Documents/loan_approval/venv/lib/python3.10/site-packages/joblib/externals/loky/backend/queues.py", line 159, in _feed
#     obj_ = dumps(obj, reducers=reducers)
#   File "/home/martin/Documents/loan_approval/venv/lib/python3.10/site-packages/joblib/externals/loky/backend/reduction.py", line 215, in dumps
#     dump(obj, buf, reducers=reducers, protocol=protocol)
#   File "/home/martin/Documents/loan_approval/venv/lib/python3.10/site-packages/joblib/externals/loky/backend/reduction.py", line 208, in dump
#     _LokyPickler(file, reducers=reducers, protocol=protocol).dump(obj)
#   File "/home/martin/Documents/loan_approval/venv/lib/python3.10/site-packages/joblib/externals/cloudpickle/cloudpickle_fast.py", line 632, in dump
#     return Pickler.dump(self, obj)
#   File "/home/martin/Documents/loan_approval/venv/lib/python3.10/site-packages/joblib/_memmapping_reducer.py", line 446, in __call__
#     for dumped_filename in dump(a, filename):
#   File "/home/martin/Documents/loan_approval/venv/lib/python3.10/site-packages/joblib/numpy_pickle.py", line 553, in dump
#     NumpyPickler(f, protocol=protocol).dump(value)
#   File "/usr/lib/python3.10/pickle.py", line 487, in dump
#     self.save(obj)
#   File "/home/martin/Documents/loan_approval/venv/lib/python3.10/site-packages/joblib/numpy_pickle.py", line 352, in save
#     wrapper.write_array(obj, self)
#   File "/home/martin/Documents/loan_approval/venv/lib/python3.10/site-packages/joblib/numpy_pickle.py", line 134, in write_array
#     pickler.file_handle.write(chunk.tobytes('C'))
# OSError: [Errno 28] No space left on device
# """
#
# The above exception was the direct cause of the following exception:
#
# PicklingError                             Traceback (most recent call last)
# File <timed exec>:8
#
# File ~/Documents/loan_approval/venv/lib/python3.10/site-packages/sklearn/base.py:1351, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1344     estimator._validate_params()
#    1346 with config_context(
#    1347     skip_parameter_validation=(
#    1348         prefer_skip_nested_validation or global_skip_validation
#    1349     )
#    1350 ):
# -> 1351     return fit_method(estimator, *args, **kwargs)
#
# File ~/Documents/loan_approval/venv/lib/python3.10/site-packages/sklearn/model_selection/_search.py:970, in BaseSearchCV.fit(self, X, y, **params)
#     964     results = self._format_results(
#     965         all_candidate_params, n_splits, all_out, all_more_results
#     966     )
#     968     return results
# --> 970 self._run_search(evaluate_candidates)
#     972 # multimetric is determined here because in the case of a callable
#     973 # self.scoring the return type is only known after calling
#     974 first_test_score = all_out[0]["test_scores"]
#
# File ~/Documents/loan_approval/venv/lib/python3.10/site-packages/sklearn/model_selection/_search.py:1914, in RandomizedSearchCV._run_search(self, evaluate_candidates)
#    1912 def _run_search(self, evaluate_candidates):
#    1913     """Search n_iter candidates from param_distributions"""
# -> 1914     evaluate_candidates(
#    1915         ParameterSampler(
#    1916             self.param_distributions, self.n_iter, random_state=self.random_state
#    1917         )
#    1918     )
#
# File ~/Documents/loan_approval/venv/lib/python3.10/site-packages/sklearn/model_selection/_search.py:916, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     908 if self.verbose > 0:
#     909     print(
#     910         "Fitting {0} folds for each of {1} candidates,"
#     911         " totalling {2} fits".format(
#     912             n_splits, n_candidates, n_candidates * n_splits
#     913         )
#     914     )
# --> 916 out = parallel(
#     917     delayed(_fit_and_score)(
#     918         clone(base_estimator),
#     919         X,
#     920         y,
#     921         train=train,
#     922         test=test,
#     923         parameters=parameters,
#     924         split_progress=(split_idx, n_splits),
#     925         candidate_progress=(cand_idx, n_candidates),
#     926         **fit_and_score_kwargs,
#     927     )
#     928     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     929         enumerate(candidate_params),
#     930         enumerate(cv.split(X, y, **routed_params.splitter.split)),
#     931     )
#     932 )
#     934 if len(out) < 1:
#     935     raise ValueError(
#     936         "No fits were performed. "
#     937         "Was the CV iterator empty? "
#     938         "Were there no candidates?"
#     939     )
#
# File ~/Documents/loan_approval/venv/lib/python3.10/site-packages/sklearn/utils/parallel.py:67, in Parallel.__call__(self, iterable)
#      62 config = get_config()
#      63 iterable_with_config = (
#      64     (_with_config(delayed_func, config), args, kwargs)
#      65     for delayed_func, args, kwargs in iterable
#      66 )
# ---> 67 return super().__call__(iterable_with_config)
#
# File ~/Documents/loan_approval/venv/lib/python3.10/site-packages/joblib/parallel.py:1952, in Parallel.__call__(self, iterable)
#    1946 # The first item from the output is blank, but it makes the interpreter
#    1947 # progress until it enters the Try/Except block of the generator and
#    1948 # reach the first `yield` statement. This starts the aynchronous
#    1949 # dispatch of the tasks to the workers.
#    1950 next(output)
# -> 1952 return output if self.return_generator else list(output)
#
# File ~/Documents/loan_approval/venv/lib/python3.10/site-packages/joblib/parallel.py:1595, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1592     yield
#    1594     with self._backend.retrieval_context():
# -> 1595         yield from self._retrieve()
#    1597 except GeneratorExit:
#    1598     # The generator has been garbage collected before being fully
#    1599     # consumed. This aborts the remaining tasks if possible and warn
#    1600     # the user if necessary.
#    1601     self._exception = True
#
# File ~/Documents/loan_approval/venv/lib/python3.10/site-packages/joblib/parallel.py:1699, in Parallel._retrieve(self)
#    1692 while self._wait_retrieval():
#    1693
#    1694     # If the callback thread of a worker has signaled that its task
#    1695     # triggered an exception, or if the retrieval loop has raised an
#    1696     # exception (e.g. `GeneratorExit`), exit the loop and surface the
#    1697     # worker traceback.
#    1698     if self._aborting:
# -> 1699         self._raise_error_fast()
#    1700         break
#    1702     # If the next job is not ready for retrieval yet, we just wait for
#    1703     # async callbacks to progress.
#
# File ~/Documents/loan_approval/venv/lib/python3.10/site-packages/joblib/parallel.py:1734, in Parallel._raise_error_fast(self)
#    1730 # If this error job exists, immediatly raise the error by
#    1731 # calling get_result. This job might not exists if abort has been
#    1732 # called directly or if the generator is gc'ed.
#    1733 if error_job is not None:
# -> 1734     error_job.get_result(self.timeout)
#
# File ~/Documents/loan_approval/venv/lib/python3.10/site-packages/joblib/parallel.py:736, in BatchCompletionCallBack.get_result(self, timeout)
#     730 backend = self.parallel._backend
#     732 if backend.supports_retrieve_callback:
#     733     # We assume that the result has already been retrieved by the
#     734     # callback thread, and is stored internally. It's just waiting to
#     735     # be returned.
# --> 736     return self._return_or_raise()
#     738 # For other backends, the main thread needs to run the retrieval step.
#     739 try:
#
# File ~/Documents/loan_approval/venv/lib/python3.10/site-packages/joblib/parallel.py:754, in BatchCompletionCallBack._return_or_raise(self)
#     752 try:
#     753     if self.status == TASK_ERROR:
# --> 754         raise self._result
#     755     return self._result
#     756 finally:
#
# PicklingError: Could not pickle the task to send it to the workers.
